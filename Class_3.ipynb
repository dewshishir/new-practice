# %% [markdown]
# <a href="https://colab.research.google.com/github/dewshishir/new-practice/blob/main/Class_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
image_path ='/'
image = plt.imread(image_path)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3218639908.py in <cell line: 0>()
#       1 image_path ='/'
# ----> 2 image = plt.imread(image_path)
#
# NameError: name 'plt' is not defined

# %%
plt.imshow(image)

# %% [markdown]
# open cv

# %%
import cv2
from matplotlib import pyplot as plt
from google.colab.patches import cv2_imshow

# %%
image_path = '/content/images.jpg'

# %%
image = cv2.imread(image_path)

plt.imshow(image)
#matplotlib ei kaj krtese

# %%
image_dir = '/content/images.jpg' #absulate path
image_dir='images.jpg' #relative path
image1 = cv2.imread(image_dir)
cv2_imshow(image1)
#eikhane open cv use hcce o jane ami to bgr e nichi ekn show korar somoi jeno rgb kre dei
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>

# %%
cv2.imwrite('output_orange.jpg',image1)
# Out:
# True

# %%
cv2.imwrite('output_orange1.jpg',image)
# Out:
# True

# %% [markdown]
# # colourspace conversion
# # doc opencv org convertion
# https://docs.opencv.org/3.4/d8/d01/group__imgproc__color__conversions.html

# %%
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
plt.imshow(image_rgb)

# %%
cv2_imshow(image_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=225x225>
